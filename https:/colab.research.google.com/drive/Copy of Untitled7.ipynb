# %%
import pandas as pd

# %%
#df = pd.read_csv('fruits_data_with_colors.txt', sep='\t')
df = pd.read_table('fruits_data_with_colors.txt')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.columns
# Out:
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')

# %%
fname = df['fruit_name'].unique()
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fsize = df.groupby(df['fruit_name'],sort = False).size()
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon        2
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(fname,fsize,color = ['r','blue','orange','y'])
plt.title('fruits vs count')
plt.xlabel('fruits name')
plt.ylabel('count')
plt.show()

# %%
x = df.iloc[:,[3,4,5,6]].values
y = df.iloc[:,1].values
print(x,y)
# Out:
# [[192.     8.4    7.3    0.55]
#  [180.     8.     6.8    0.59]
#  [176.     7.4    7.2    0.6 ]
#  [ 86.     6.2    4.7    0.8 ]
#  [ 84.     6.     4.6    0.79]
#  [ 80.     5.8    4.3    0.77]
#  [ 80.     5.9    4.3    0.81]
#  [ 76.     5.8    4.     0.81]
#  [178.     7.1    7.8    0.92]
#  [172.     7.4    7.     0.89]
#  [166.     6.9    7.3    0.93]
#  [172.     7.1    7.6    0.92]
#  [154.     7.     7.1    0.88]
#  [164.     7.3    7.7    0.7 ]
#  [152.     7.6    7.3    0.69]
#  [156.     7.7    7.1    0.69]
#  [156.     7.6    7.5    0.67]
#  [168.     7.5    7.6    0.73]
#  [162.     7.5    7.1    0.83]
#  [162.     7.4    7.2    0.85]
#  [160.     7.5    7.5    0.86]
#  [156.     7.4    7.4    0.84]
#  [140.     7.3    7.1    0.87]
#  [170.     7.6    7.9    0.88]
#  [342.     9.     9.4    0.75]
#  [356.     9.2    9.2    0.75]
#  [362.     9.6    9.2    0.74]
#  [204.     7.5    9.2    0.77]
#  [140.     6.7    7.1    0.72]
#  [160.     7.     7.4    0.81]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (33, 4)
# (12, 4)
# (33,)
# (12,)

# %%
from sklearn.preprocessing import MinMaxScaler # Range 0 to 1
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train) 
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[0.36363636, 0.47368421, 0.64615385, 0.64864865],
#        [0.34965035, 0.42105263, 0.49230769, 0.13513514],
#        [0.41258741, 0.36842105, 0.96923077, 0.40540541],
#        [0.3006993 , 0.44736842, 0.47692308, 0.75675676],
#        [0.27972028, 0.5       , 0.47692308, 0.37837838],
#        [0.22377622, 0.39473684, 0.47692308, 0.86486486],
#        [0.27972028, 0.47368421, 0.53846154, 0.32432432],
#        [0.27272727, 0.34210526, 0.53846154, 0.62162162],
#        [0.35664336, 0.34210526, 0.58461538, 1.        ],
#        [0.30769231, 0.39473684, 0.56923077, 0.40540541],
#        [0.01398601, 0.        , 0.04615385, 0.59459459],
#        [0.32167832, 0.44736842, 0.55384615, 0.48648649],
#        [0.30769231, 0.36842105, 0.46153846, 0.67567568],
#        [0.26573427, 0.47368421, 0.50769231, 0.37837838],
#        [0.25874126, 0.34210526, 0.6       , 0.54054054],
#        [0.        , 0.        , 0.        , 0.7027027 ],
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 7,metric = 'euclidean')

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['orange', 'orange', 'orange', 'mandarin', 'apple', 'orange',
#        'orange', 'apple', 'orange', 'apple', 'orange', 'apple'],
#       dtype=object)

# %%
y_test
# Out:
# array(['orange', 'orange', 'orange', 'mandarin', 'apple', 'orange',
#        'orange', 'apple', 'orange', 'orange', 'orange', 'apple'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)*100
# Out:
# 91.66666666666666

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[3, 0, 0],
#        [0, 1, 0],
#        [1, 0, 7]])

# %%
a = plt.subplot(211)
a.scatter(df['width'],df['height'])
a.set_title('width vs height')
a = plt.subplot(212)
a.scatter(df['width'],df['color_score'])
a.set_title('width vs colorscore')
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
fig = plt.figure()
ax1 = fig.add_subplot(111,projection='3d')
ax1.scatter(df['width'],df['height'],df['color_score'])
ax1.set_xlabel('width')
ax1.set_ylabel('height')
ax1.set_zlabel('color_score')
plt.show()
